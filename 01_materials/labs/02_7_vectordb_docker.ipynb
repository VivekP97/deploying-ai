# %% [markdown]
# # Vector DB
#
# In this notebook, we use a containerized version of Chroma DB. To set up, you will need the following:
#
# 1. Install [Docker Desktop](https://www.docker.com/products/docker-desktop/) by following the link and Download Docker Desktop for your operating system.
# 2. In a terminal window, navigate to the folder ./05_src/chromadb/. For example, on Windows, you would use `cd .\05_src\chromadb`.
# 3. Run the command `docker compose up -d`, which will start the Chroma DB server.

# %% [markdown]
# ## Downloading Batch Results
#
# In the previous notebook, we had created batch processes. We will start by consulting the status of our batch processes by identifying them throught their descriptions.

# %%
# %load_ext dotenv
# %dotenv ../../05_src/.secrets
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
#batch_description = 'Pitchfork reviews content embeddings 2025-10-18 12:17:17'
#batch_description = 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-28 00:45:37'
batch_description = 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-28 14:05:36'

# %%
from openai import OpenAI
import os

client = OpenAI(base_url='https://k7uffyg03f.execute-api.us-east-1.amazonaws.com/prod/openai/v1', 
                default_headers={"x-api-key": os.getenv('API_GATEWAY_KEY')})

batch_processes = client.batches.list().to_dict()
batch_info= [
    {'batch_id': batch['id'],
     'description': batch['metadata']['description'],
    'status': batch['status'],
    'request_counts': batch['request_counts'],
    'output_file_id': batch['output_file_id'],
    'input_file_id': batch['input_file_id']}
            for batch in batch_processes['data'] if batch['metadata']['description'] == "Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04"
    ]
batch_info
# Out:
# [{'batch_id': 'batch_69a33ebdfe248190b5c4b3f463affa35',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-GpnQVKhUHPaRAMmkvpHKgy',
#   'input_file_id': 'file-7A3uKvF2emmFLKrsqA5fDs'},
#  {'batch_id': 'batch_69a33ebdbd148190aba76765986fa221',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-F4gW4LJ4r4gqLvFdFVoZvj',
#   'input_file_id': 'file-HVeSZ348VxpskABMtK2SUL'},
#  {'batch_id': 'batch_69a33ebd78508190bb89204e01d838db',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-8uKiMCT7JMJEs78bsr4egN',
#   'input_file_id': 'file-JB3MyvEUsKnfJTmJGwVLsN'},
#  {'batch_id': 'batch_69a33ebd324881909bdf8693a012e422',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-W2pNJfzKasUoFyHsnEMro3',
#   'input_file_id': 'file-B4ju8evkt7KXRZycnJp1Sz'},
#  {'batch_id': 'batch_69a33ebcfac481909b2523c6a23ce5cb',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-VoXp6VtuuZxVoWsrzDipfW',
#   'input_file_id': 'file-LVkUbdt9Z1GW6G33Wp4zpj'},
#  {'batch_id': 'batch_69a33ebcc0988190961e483ad098e945',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-MQumi8rW5fNS1B3foX8u7y',
#   'input_file_id': 'file-3EHYMNhLnMDLK6R5v4uyQJ'},
#  {'batch_id': 'batch_69a33ebc80248190b318b6a50c813c9d',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-DepP729wwo5jvH2GV1XhQy',
#   'input_file_id': 'file-4U6oSGw9VUoondAb2JBjoE'},
#  {'batch_id': 'batch_69a33ebc38fc8190b9b8e0ee95abef41',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-KzH2GDE14uPZPadV5smjt9',
#   'input_file_id': 'file-BmDPtzoe1SYtUtJyYF47Wt'},
#  {'batch_id': 'batch_69a33ebbf1a08190a938a00276e91888',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-5QPd6e6uYCUYprSztyywTJ',
#   'input_file_id': 'file-8syDSQQhqAk4A1XiLPNUEt'},
#  {'batch_id': 'batch_69a33ebba9ec8190b082f68a6ea4ef31',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-76V2rqbnWudMJXsUfWzPaf',
#   'input_file_id': 'file-7NDrNWN1d3eRMVLrfTRkrh'},
#  {'batch_id': 'batch_69a33ebb540881909a51a00bd6de9a4d',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Kt57avakXasbuyPNTVSQ9o',
#   'input_file_id': 'file-JtuKgDnsC3XsZdFBoij4AS'},
#  {'batch_id': 'batch_69a33ebb0f408190b2530a0e20b3afe4',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-W23EFnNL3bjgrRs9ykXHgG',
#   'input_file_id': 'file-1dzLULSWa3yV9HbHJdk5Ak'},
#  {'batch_id': 'batch_69a33ebace64819099c5d52b3cead7f5',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-FeR24T4E8urGSXQmu8UVWC',
#   'input_file_id': 'file-7a6gnBWyigovdain1V1fYp'},
#  {'batch_id': 'batch_69a33eba6e3c8190bf7ff8e4b60d57a7',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-BykBvpDGg7VokVdxTbUeCy',
#   'input_file_id': 'file-6oYuwGbzi6x1XMPypY7auD'},
#  {'batch_id': 'batch_69a33eba2c048190a298befe2af22fdc',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-6QykLxAjsmBRmmxJYfxAgz',
#   'input_file_id': 'file-8xcgpoahqw5je3V2xiCrRN'},
#  {'batch_id': 'batch_69a33eb9e67481908d680e4141c860bc',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-B7YxQEsi9e5R7eQWJs7YUN',
#   'input_file_id': 'file-Srkdh84hoUQrVAredeWtdf'},
#  {'batch_id': 'batch_69a33eb99dec81909ffc32f9e1ebe6a0',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'in_progress',
#   'request_counts': {'completed': 969, 'failed': 0, 'total': 1000},
#   'output_file_id': None,
#   'input_file_id': 'file-J6EmhNj9jGpMMGXcM4WPWL'},
#  {'batch_id': 'batch_69a33eb962e08190a57fefa134f364a5',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-AD5ycbaXQCbVTZRsFDJkBV',
#   'input_file_id': 'file-P5DxzJq5QvW5fZvvasSEjH'},
#  {'batch_id': 'batch_69a33eb906508190aec288d07e767900',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-3tpCyHJEXTy2uN48UNuNJQ',
#   'input_file_id': 'file-8oN2eYdwdnjbr1AvvM1udK'},
#  {'batch_id': 'batch_69a33eb8ac5c819087e749f282190c6f',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-APgE5V8MwGWB4SkKqESbKn',
#   'input_file_id': 'file-XYYUeFLhE5FUY53wy2rSSK'}]

# %% [markdown]
# When the status of the batches is complete, we can query the `output_file_id` where their results will be stored.
#
# More generally, we will require the original text and the embeddings of that original text mapped through the `custom_id`.

# %%
batch_complete = [
    batch  for batch in batch_info if batch['status'] == 'completed'
]
batch_complete
# Out:
# [{'batch_id': 'batch_69a33ebdfe248190b5c4b3f463affa35',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-GpnQVKhUHPaRAMmkvpHKgy',
#   'input_file_id': 'file-7A3uKvF2emmFLKrsqA5fDs'},
#  {'batch_id': 'batch_69a33ebdbd148190aba76765986fa221',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-F4gW4LJ4r4gqLvFdFVoZvj',
#   'input_file_id': 'file-HVeSZ348VxpskABMtK2SUL'},
#  {'batch_id': 'batch_69a33ebd78508190bb89204e01d838db',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-8uKiMCT7JMJEs78bsr4egN',
#   'input_file_id': 'file-JB3MyvEUsKnfJTmJGwVLsN'},
#  {'batch_id': 'batch_69a33ebd324881909bdf8693a012e422',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-W2pNJfzKasUoFyHsnEMro3',
#   'input_file_id': 'file-B4ju8evkt7KXRZycnJp1Sz'},
#  {'batch_id': 'batch_69a33ebcfac481909b2523c6a23ce5cb',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-VoXp6VtuuZxVoWsrzDipfW',
#   'input_file_id': 'file-LVkUbdt9Z1GW6G33Wp4zpj'},
#  {'batch_id': 'batch_69a33ebcc0988190961e483ad098e945',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-MQumi8rW5fNS1B3foX8u7y',
#   'input_file_id': 'file-3EHYMNhLnMDLK6R5v4uyQJ'},
#  {'batch_id': 'batch_69a33ebc80248190b318b6a50c813c9d',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-DepP729wwo5jvH2GV1XhQy',
#   'input_file_id': 'file-4U6oSGw9VUoondAb2JBjoE'},
#  {'batch_id': 'batch_69a33ebc38fc8190b9b8e0ee95abef41',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-KzH2GDE14uPZPadV5smjt9',
#   'input_file_id': 'file-BmDPtzoe1SYtUtJyYF47Wt'},
#  {'batch_id': 'batch_69a33ebbf1a08190a938a00276e91888',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-5QPd6e6uYCUYprSztyywTJ',
#   'input_file_id': 'file-8syDSQQhqAk4A1XiLPNUEt'},
#  {'batch_id': 'batch_69a33ebba9ec8190b082f68a6ea4ef31',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-76V2rqbnWudMJXsUfWzPaf',
#   'input_file_id': 'file-7NDrNWN1d3eRMVLrfTRkrh'},
#  {'batch_id': 'batch_69a33ebb540881909a51a00bd6de9a4d',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Kt57avakXasbuyPNTVSQ9o',
#   'input_file_id': 'file-JtuKgDnsC3XsZdFBoij4AS'},
#  {'batch_id': 'batch_69a33ebb0f408190b2530a0e20b3afe4',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-W23EFnNL3bjgrRs9ykXHgG',
#   'input_file_id': 'file-1dzLULSWa3yV9HbHJdk5Ak'},
#  {'batch_id': 'batch_69a33ebace64819099c5d52b3cead7f5',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-FeR24T4E8urGSXQmu8UVWC',
#   'input_file_id': 'file-7a6gnBWyigovdain1V1fYp'},
#  {'batch_id': 'batch_69a33eba6e3c8190bf7ff8e4b60d57a7',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-BykBvpDGg7VokVdxTbUeCy',
#   'input_file_id': 'file-6oYuwGbzi6x1XMPypY7auD'},
#  {'batch_id': 'batch_69a33eba2c048190a298befe2af22fdc',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-6QykLxAjsmBRmmxJYfxAgz',
#   'input_file_id': 'file-8xcgpoahqw5je3V2xiCrRN'},
#  {'batch_id': 'batch_69a33eb9e67481908d680e4141c860bc',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-B7YxQEsi9e5R7eQWJs7YUN',
#   'input_file_id': 'file-Srkdh84hoUQrVAredeWtdf'},
#  {'batch_id': 'batch_69a33eb962e08190a57fefa134f364a5',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-AD5ycbaXQCbVTZRsFDJkBV',
#   'input_file_id': 'file-P5DxzJq5QvW5fZvvasSEjH'},
#  {'batch_id': 'batch_69a33eb906508190aec288d07e767900',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-3tpCyHJEXTy2uN48UNuNJQ',
#   'input_file_id': 'file-8oN2eYdwdnjbr1AvvM1udK'},
#  {'batch_id': 'batch_69a33eb8ac5c819087e749f282190c6f',
#   'description': 'Pitchfork reviews content embeddings (yks) 2026-02-28 14:15:04',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-APgE5V8MwGWB4SkKqESbKn',
#   'input_file_id': 'file-XYYUeFLhE5FUY53wy2rSSK'}]

# %% [markdown]
# Before we download all results, examine the response of the file API:

# %%
response = client.files.content(batch_complete[0]['output_file_id'])
text_response = response.text
lines = text_response.split('\n')
print(lines[0])
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 response = client.files.content(batch_complete[0]['output_file_id'])
#       2 text_response = response.text
#       3 lines = text_response.split('\n')
#
# File c:\Users\Vivek\Documents\Career\Courses and Certifications\2026 DSI - Deploying AI Microcredential\Repositories\deploying-ai\deploying-ai-env\Lib\site-packages\openai\resources\files.py:290, in Files.content(self, file_id, extra_headers, extra_query, extra_body, timeout)
#     288     raise ValueError(f"Expected a non-empty value for `file_id` but received {file_id!r}")
#     289 extra_headers = {"Accept": "application/binary", **(extra_headers or {})}
# --> 290 return self._get(
#     291     f"/files/{file_id}/content",
#     292     options=make_request_options(
#     293         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     294     ),
#     295     cast_to=_legacy_response.HttpxBinaryResponseContent,
#     296 )
#
# File c:\Users\Vivek\Documents\Career\Courses and Certifications\2026 DSI - Deploying AI Microcredential\Repositories\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_base_client.py:1228, in SyncAPIClient.get(self, path, cast_to, options, stream, stream_cls)
#    1225 opts = FinalRequestOptions.construct(method="get", url=path, **options)
#    1226 # cast is required because mypy complains about returning Any even though
#    1227 # it understands the type variables
# -> 1228 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Vivek\Documents\Career\Courses and Certifications\2026 DSI - Deploying AI Microcredential\Repositories\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# InternalServerError: Error code: 502 - {'message': 'Internal server error'}

# %% [markdown]
# For our results database, we will need to map the original text to their embeddings.

# %%
import json 

def get_text_and_embeddings(batch):
    embedding_lines =  get_content_from_file(batch, 'output_file_id')
    text_lines = get_content_from_file(batch, 'input_file_id')
    return embedding_lines, text_lines

def get_content_from_file(batch, key):
    file = client.files.content(batch[key])
    text = file.text
    lines = text.split('\n')
    content_lines = [json.loads(line) for line in lines if line.strip()]
    return content_lines

# %% [markdown]
# Notice that the response is also a .jsonl file. Therefore, we can process it line-by-line and use the `custom_id` to map to the original document chunk.
#
# The function below:
#
# - Creates a dictionary, `text_dict`, with keys given by each `custom_id` and value equal to the text.
# - Iterate over all embedding items and use the dictionary defined above to map the embeddings to their input text.

# %%
def create_chroma_inputs(embedding_lines, text_lines):
    chroma_inputs = []
    text_dict = {item['custom_id']: item['body']['input'] for item in text_lines}
    for embed_item in embedding_lines:
        custom_id = embed_item['custom_id']
        text = text_dict.get(custom_id, "")
        chroma_input = {
            'id': embed_item['custom_id'],
            'embedding': embed_item['response']['body']['data'][0]['embedding'],
            'text': text
        }
        chroma_inputs.append(chroma_input)
    return chroma_inputs

# %% [markdown]
# A couple of functions to control the logic flow:

# %%
from tqdm import tqdm

def process_batch_for_chromadb(batch):
    embedding_lines, text_lines = get_text_and_embeddings(batch)
    chroma_inputs = create_chroma_inputs(embedding_lines, text_lines)
    return chroma_inputs

def process_batches_for_chromadb(batches):
    all_chroma_inputs = []
    for batch in tqdm(batches, desc="Processing batches"):
        chroma_inputs = process_batch_for_chromadb(batch)
        all_chroma_inputs.extend(chroma_inputs)
    return all_chroma_inputs

# %% [markdown]
# Now, we can create our input dictionaries.

# %%
chroma_inputs = process_batches_for_chromadb(batch_complete)

# %%
chroma_inputs[1]

# %% [markdown]
# # Load Embeddings to Chroma

# %%
import chromadb
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction
import os


def setup_collection(chroma_url:str="http://localhost:8000",
                     collection_name: str = "pitchfork_reviews"):
    chroma_client = chromadb.HttpClient(host=chroma_url)
    collections = chroma_client.list_collections()
    if collection_name in [col.name for col in collections]:
        chroma_client.delete_collection(name=collection_name)

    collection = chroma_client.create_collection(
        name=collection_name,
        embedding_function=OpenAIEmbeddingFunction(
            api_key = os.getenv("OPENAI_API_KEY"),
            model_name="text-embedding-3-small")
        )
    return collection

def load_embeddings_to_db(chroma_inputs:list[dict], 
                          collection_name:str,
                          chroma_url:str="http://localhost:8000",
                          batch_size:int= 1000
                          ):

    
    collection = setup_collection(chroma_url=chroma_url, collection_name=collection_name)

    for i in tqdm(range(0, len(chroma_inputs), batch_size)):
        batch = chroma_inputs[i:i + batch_size]
        collection.add(
            documents=[item['text'] for item in batch],
            embeddings=[item['embedding'] for item in batch],
            ids=[item['id'] for item in batch]
        )

# %%
vector_db_client_url:str="http://localhost:8000"
load_embeddings_to_db(chroma_inputs=chroma_inputs,
                      collection_name="pitchfork_reviews",
                      chroma_url=vector_db_client_url, 
                      batch_size=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 vector_db_client_url:str="http://localhost:8000"
# ----> 2 load_embeddings_to_db(chroma_inputs=chroma_inputs,
#       3                       collection_name="pitchfork_reviews",
#       4                       chroma_url=vector_db_client_url,
#       5                       batch_size=1000)
#
# NameError: name 'chroma_inputs' is not defined

# %% [markdown]
# # Additional Details
#
# We will use a simple database to store additional details about the reviews. In this case, we load the jsonl files, and use pandas to create a few tables in a sql database. The connection string to the database is included in the .secrets file.

# %%
import json

def load_jsonl(file:str):
    data = []
    with open(file, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                data.append(json.loads(line))
    return data

# %%
import pandas as pd
import sqlalchemy as sa
import os

doc_folder = "../../05_src/documents/"
tables = ["artists", "reviews", "labels", "genres"]

def upload_tables_to_sql(tables:list[str], doc_folder:str):
    engine = sa.create_engine(os.getenv("SQL_URL"))
    for table_name in tables:
        file_path = os.path.join(doc_folder, f"pitchfork_{table_name}.jsonl")
        data = load_jsonl(file_path)
        df = pd.DataFrame(data)
        with engine.connect() as conn:
            df.to_sql(table_name, conn, if_exists='replace', index=False)
        print(f"Loaded {df.shape} records from {file_path}")

upload_tables_to_sql(tables=tables, doc_folder=doc_folder)

# %%
def additional_details(review_id:str):
    import sqlalchemy as sa
    import pandas as pd
    import os

    engine = sa.create_engine(os.getenv("SQL_URL"))
    query = f"""
    SELECT r.reviewid,
		r.title,
		r.artist,
		r.score,
		g.genre
    FROM reviews AS r
    LEFT JOIN genres as g
	    ON r.reviewid = g.reviewid
    WHERE r.reviewid = '{review_id}'
    """
    with engine.connect() as conn:
        result = pd.read_sql(query, conn)
    if not result.empty:
        row = result.iloc[0]
        details = {
            "reviewid": row['reviewid'],
            "album": row['title'],
            "score": row['score'],
            "artist": row['artist']
        }
        return details
    else:
        return {}
    
def get_reviewid_from_custom_id(custom_id:str):
    return custom_id.split('_')[0]

# %% [markdown]
# # Prompt Generator
#
# Here we create a prompt with the context gathered through the different data operations.

# %%
chroma = chromadb.HttpClient(host=vector_db_client_url)
collection = chroma.get_collection(name="pitchfork_reviews", 
                                   embedding_function=OpenAIEmbeddingFunction(
                                       api_key = os.getenv("OPENAI_API_KEY"),
                                       model_name="text-embedding-3-small")
                                   )

# %%
collection.query(
    query_texts=["A great album with stunning vocals and production."],
    n_results=3
)

# %%
def get_context_data(query:str, collection:chromadb.api.models.Collection, top_n:int):
    results = collection.query(
        query_texts=[query],
        n_results=top_n
    )
    context_data = []
    for idx, custom_id in enumerate(results['ids'][0]):
        review_id = get_reviewid_from_custom_id(custom_id)
        details = additional_details(review_id)
        details['text'] = results['documents'][0][idx]
        context_data.append(details)
    return context_data

def generate_prompt(query:str, collection:chromadb.api.models.Collection, top_n:int):
    context_data = get_context_data(query, collection, top_n)
    prompt = f"Given a query, provide a detailed response using the context from relevant Pitchfork reviews. The context will contain references to {top_n} album reviews.\n\n"
    prompt += f"The score is numeric and its scale is from 0 to 10, with 10 being the highest rating. Any album with a score greater than 8.0 is considered a must-listen; album with a score greater than 6.5 is good.\n\n"
    prompt += f"<query>{query}</query>\n\n"
    prompt += "<context>\n"
    for k, context in enumerate(context_data):
        prompt += f"<album {k}>\n"
        prompt += f"- Album Title: {context.get('album', 'N/A')}\n" 
        prompt += f"- Album Artist: {context.get('artist', 'N/A')}\n"
        prompt += f"- Album Score: {context.get('score', 'N/A')}\n"
        prompt += f"- Review Quote: {context.get('text', 'N/A')}\n"
        prompt += f"</album {k}>\n\n"
    prompt += "</context>\n\n"
    prompt += "\nBased on the context and nothing else, provide a detailed response to the query."
    return prompt

def generate_response(query:str, collection:chromadb.api.models.Collection, top_n:int=1):
    prompt = generate_prompt(query, collection, top_n)
    print("Generated Prompt:\n", prompt)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that provides information based on Pitchfork reviews."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=500,
        temperature=0.7
    )
    return response.choices[0].message.content

# %% [markdown]
# # Query
#
# We can now use chroma's similarity function to query the database. Notice that the query itself needs to be converted to embeddings, so we must provide an `embedding_function`. In this case, we use `OpenAIEmbeddingFunction()` to get compatible embeddings using model `text-embedding-3-small`.

# %%
response = generate_response("What are some highly rated albums by emerging indie artists?", collection, 3)

# %%
print(response)

# %% [markdown]
# **Note**: Try changing the top_n parameter to 1 and re-run the query.
